# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def my_bisection(f, a, b, tol): 
    
    if np.sign(f(a)) == np.sign(f(b)):
        raise Exception(
         "The scalars a and b do not bound a root")
        
    
    m = (a + b)/2
    
    if np.abs(f(m)) < tol:
        return m
    elif np.sign(f(a)) == np.sign(f(m)):     
        return my_bisection(f, m, b, tol)
    elif np.sign(f(b)) == np.sign(f(m)):
        return my_bisection(f, a, m, tol)
f = lambda x: x**3 -(5*x) + 3

r1 = my_bisection(f, 1,3, 0.001)

#   -100,100   0,1  1,3

# 2.4908065795898438 1.834228515625 0.65673828125
print("r1 =", r1)

print("f(r1) =", f(r1))
# Out:
# r1 = 1.834228515625
# f(r1) = -7.471149729099125e-05

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: x**3-x-4
f_prime = lambda x: 3*(x**2)-1

x0 = 1.4
tol = 1e-3

x_values = [x0]
while abs(f(x0)) >= tol:
    x0 = x0 - f(x0) / f_prime(x0)
    x_values.append(x0)

root_approximation = x_values[-1]

print("Approximated root using Newton-Raphson:", root_approximation)
print("f(root) =", f(x_values[-1]))
# Out:
# Approximated root using Newton-Raphson: 1.7964108535288241
# f(root) = 0.0007721591869751521

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: 2*(x**3)-2*x-5
f_prime = lambda x: 6*(x**2)-2

x0 = 3
tol = 1e-3

x_values = [x0]
newton=[]
while abs(f(x0)) >= tol:
    x0 = x0 - f(x0) / f_prime(x0)
    x_values.append(x0)
    newton.append(f(x0))

root_approximation = x_values[-1]

print("Approximated root using Newton-Raphson:", root_approximation)
plt.plot(x_values, 'bo-')
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of Newton-Raphson Method')
plt.grid()
plt.show()
# Out:
# Approximated root using Newton-Raphson: 1.6005985575008426

# %%
f = lambda x: 2*(x**3)-2*x-5
x_values = []
secant= []
def secant_method(x0, x1, tolerance=1e-3, max_iterations=100):
    iteration = 0
    while iteration < max_iterations:
        fx0 = f(x0)
        fx1 = f(x1)
        secant.append(fx1)
        x_values.append(x1)
        if abs(fx1) < tolerance:
            return x1
        
        # Calculate the next approximation using the secant formula
        x_next = x1 - fx1 * (x1 - x0) / (fx1 - fx0)
        
        x0, x1 = x1, x_next # Update x0 and x1 for the next iteration
        iteration += 1
    
    raise ValueError("Secant method did not converge in {} iterations".format(max_iterations))
print("Approximated root using secant_method:", secant_method(3,4))

plt.plot(x_values, 'bo-')
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of secant_method Method')
plt.grid()
plt.show()
# Out:
# Approximated root using secant_method: 1.6005991933880834

# %%
    
plt.plot(newton, 'orange')
plt.plot(secant)
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of secant_method Method and newton ')
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: np.tan(x)-4*x
f_prime = lambda x: (1+np.tan(x)*np.tan(x))-4
# f_prime = lambda x: 1/(np.cos(x)*np.cos(x)) -4

x0 = 6
tol = 1e-3

x_values = [x0]
newton=[]
while abs(f(x0)) >= tol:
    x0 = x0 - f(x0) / f_prime(x0)
    x_values.append(x0)
    newton.append(f(x0))

root_approximation = x_values[-1]

print("Approximated root using Newton-Raphson:", root_approximation)
plt.plot(x_values, 'bo-')
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of Newton-Raphson Method')
plt.grid()
plt.show()
# Out:
# Approximated root using Newton-Raphson: -1.3932496637264815

# %%
print(np.tan(root_approximation))
# Out:
# -5.573015164489364

# %%
print(4*root_approximation)
# Out:
# -5.572998654905926
