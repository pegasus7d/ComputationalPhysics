# %%
#newton raphson
import numpy as np
import matplotlib.pyplot as plt

f = lambda x: np.exp(x)-3*x
f_prime = lambda x: np.exp(x)-3

x0 = 0.5
tol = 1e-6

x_values = [x0]
while abs(f(x0)) >= tol:
    x0 = x0 - f(x0) / f_prime(x0)
    x_values.append(x0)

root_approximation = x_values[-1]

print("Approximated root using Newton-Raphson:", root_approximation)
print("Exact square root of 2:", np.sqrt(2))

# Plotting the convergence graph
plt.plot(x_values, 'bo-')
plt.axhline(y=np.sqrt(2), color='r', linestyle='--', label='Exact sqrt(2)')
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of Newton-Raphson Method')
plt.legend()
plt.grid()
plt.show()


print(x_values)
# Out:
# Approximated root using Newton-Raphson: 0.6190612833553127
# Exact square root of 2: 1.4142135623730951
# [0.5, 0.6100596549589618, 0.6189967797415397, 0.6190612833553127]

# %%
#bisection

def my_bisection(f, a, b, tol): 
    
    if np.sign(f(a)) == np.sign(f(b)):
        raise Exception(
         "The scalars a and b do not bound a root")
        
    
    m = (a + b)/2
    
    if np.abs(f(m)) < tol:
        return m
    elif np.sign(f(a)) == np.sign(f(m)):     
        return my_bisection(f, m, b, tol)
    elif np.sign(f(b)) == np.sign(f(m)):
        return my_bisection(f, a, m, tol)
f = lambda x: x**3 -(5*x) + 3

r1 = my_bisection(f, 1,3, 0.001)

#   -100,100   0,1  1,3

# 2.4908065795898438 1.834228515625 0.65673828125
print("r1 =", r1)

print("f(r1) =", f(r1))
# Out:
# r1 = 1.834228515625
# f(r1) = -7.471149729099125e-05

# %%
#secant method
f = lambda x: 2*(x**3)-2*x-5
x_values = []
secant= []
def secant_method(x0, x1, tolerance=1e-3, max_iterations=100):
    iteration = 0
    while iteration < max_iterations:
        fx0 = f(x0)
        fx1 = f(x1)
        secant.append(fx1)
        x_values.append(x1)
        if abs(fx1) < tolerance:
            return x1
        
        # Calculate the next approximation using the secant formula
        x_next = x1 - fx1 * (x1 - x0) / (fx1 - fx0)
        
        x0, x1 = x1, x_next # Update x0 and x1 for the next iteration
        iteration += 1
    
    raise ValueError("Secant method did not converge in {} iterations".format(max_iterations))
print("Approximated root using secant_method:", secant_method(3,4))

plt.plot(x_values, 'bo-')
plt.xlabel('Iteration')
plt.ylabel('Approximated Root')
plt.title('Convergence of secant_method Method')
plt.grid()
plt.show()
# Out:
# Approximated root using secant_method: 1.6005991933880834

# %%
# Euler 
import numpy as np
import matplotlib.pyplot as plt

h = 0.1
x = np.arange(1, 3 + h, h)

def f(x, y):
    return x * y

s = np.zeros(len(x))
s[0] = 5

for i in range(0, len(x) - 1):
    s[i + 1] = s[i] + h * f(x[i], s[i])

plt.plot(x, s, 'bo--', label='Approximate')
plt.plot(x, 5 * np.exp((x*x)/2 - 0.5), 'g', label='Exact')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

for xx, yy in zip(x, s):
    print("x =", xx, "y =", yy)
# Out:
# x = 1.0 y = 5.0
# x = 1.1 y = 5.5
# x = 1.2000000000000002 y = 6.105
# x = 1.3000000000000003 y = 6.8376
# x = 1.4000000000000004 y = 7.726488000000001
# x = 1.5000000000000004 y = 8.80819632
# x = 1.6000000000000005 y = 10.129425768
# x = 1.7000000000000006 y = 11.75013389088
# x = 1.8000000000000007 y = 13.747656652329603
# x = 1.9000000000000008 y = 16.222234849748933
# x = 2.000000000000001 y = 19.30445947120123
# x = 2.100000000000001 y = 23.165351365441477
# x = 2.200000000000001 y = 28.03007515218419
# x = 2.300000000000001 y = 34.19669168566472
# x = 2.4000000000000012 y = 42.06193077336761
# x = 2.5000000000000013 y = 52.15679415897584
# x = 2.6000000000000014 y = 65.1959926987198
# x = 2.7000000000000015 y = 82.14695080038696
# x = 2.8000000000000016 y = 104.32662751649146
# x = 2.9000000000000017 y = 133.53808322110908
# x = 3.0000000000000018 y = 172.26412735523073

# %%
#advanced Euler
import numpy as np
import matplotlib.pyplot as plt
h=0.1
x=np.arange(1,3+h,h)
def g(x,y):
    return x*y
y=np.zeros(len(x))

y[0]=5

for i in range(0,len(x)-1):
    y[i+1]=y[i]+h*g(x[i]+h/2,y[i]+h/2)

plt.plot(x,y,'bo--',label='Approximate')
plt.plot(x,5*np.exp((x*x)/2 - 0.5),'g',label='Exact')


plt.legend()
plt.xlabel('x')
plt.ylabel('y')
plt.title('Approximate vs Exact Solution')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
h=0.1
x=np.arange(1,3+h,h)
y=np.zeros(len(x))
y[0]=5

def g(x,y):
    return x*y

for i in range(1,len(x)):
    k1=h*g(x[i-1],y[i-1])
    k2=h*g(x[i-1]+h/2,y[i-1]+k1/2)
    y[i]=y[i-1]+k2
    
plt.plot(x, y, 'bo--', label='Approximate')
plt.plot(x, np.exp((x*x)/2 + np.log(5) - 0.5), 'g', label='Exact')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()
for xx,yy in zip(x,y):
    print("x = ",xx," y = ",yy)
# Out:
# x =  1.0  y =  5.0
# x =  1.1  y =  5.55125
# x =  1.2000000000000002  y =  6.22475540625
# x =  1.3000000000000003  y =  7.049535497578125
# x =  1.4000000000000004  y =  8.06308246374242
# x =  1.5000000000000004  y =  9.314069707992058
# x =  1.6000000000000005  y =  10.866026573086234
# x =  1.7000000000000006  y =  12.802352508410202
# x =  1.8000000000000007  y =  15.23319919094459
# x =  1.9000000000000008  y =  18.304973807798568
# x =  2.000000000000001  y =  22.21354334010876
# x =  2.100000000000001  y =  27.22269736330329
# x =  2.200000000000001  y =  33.69012968939007
# x =  2.300000000000001  y =  42.10423957931524
# x =  2.4000000000000012  y =  53.13660295508532
# x =  2.5000000000000013  y =  67.71728680596074
# x =  2.6000000000000014  y =  87.14368345842074
# x =  2.7000000000000015  y =  113.23885947004484
# x =  2.8000000000000016  y =  148.5835384821326
# x =  2.9000000000000017  y =  196.8583301349775
# x =  3.0000000000000018  y =  263.35215259631957

# %%
import numpy as np
import matplotlib.pyplot as plt

def f(x, y):
    return x * y

h = 0.1
x = np.arange(1, 3 + h, h)
y = np.zeros(len(x))


y[0] = 5


for i in range(1,len(x)):
    k1=h*g(x[i-1],y[i-1])
    k2=h*g(x[i-1]+h/2,y[i-1]+k1/2)
    k3=h*g(x[i-1]+h/2,y[i-1]+k2/2)
    k4=h*g(x[i-1]+h/2,y[i-1]+k3)
    y[i]=y[i-1]+k2
    
    
plt.plot(x, y, 'bo--', label='Approximate')
plt.plot(x, np.exp((x*x)/2 + np.log(5) - 0.5), 'g', label='Exact')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()
for xx,yy in zip(x,y):
    print("x = ",xx," y = ",yy)
# Out:
# x =  1.0  y =  5.0
# x =  1.1  y =  5.55125
# x =  1.2000000000000002  y =  6.22475540625
# x =  1.3000000000000003  y =  7.049535497578125
# x =  1.4000000000000004  y =  8.06308246374242
# x =  1.5000000000000004  y =  9.314069707992058
# x =  1.6000000000000005  y =  10.866026573086234
# x =  1.7000000000000006  y =  12.802352508410202
# x =  1.8000000000000007  y =  15.23319919094459
# x =  1.9000000000000008  y =  18.304973807798568
# x =  2.000000000000001  y =  22.21354334010876
# x =  2.100000000000001  y =  27.22269736330329
# x =  2.200000000000001  y =  33.69012968939007
# x =  2.300000000000001  y =  42.10423957931524
# x =  2.4000000000000012  y =  53.13660295508532
# x =  2.5000000000000013  y =  67.71728680596074
# x =  2.6000000000000014  y =  87.14368345842074
# x =  2.7000000000000015  y =  113.23885947004484
# x =  2.8000000000000016  y =  148.5835384821326
# x =  2.9000000000000017  y =  196.8583301349775
# x =  3.0000000000000018  y =  263.35215259631957

# %%
def F(y, u, x):
    return (10*np.sin(x))-(5*u)-(6*y)

def exact(x):
    return -6*np.exp(-3*x)+7*np.exp(-2*x)+np.sin(x)-np.cos(x)



h=0.1
xpoints = np.arange(0, 3+h, h)
ypoints = []
upoints = []
exactpoints=[]

y = 0
u = 5
s=0;
for x in xpoints:
    ypoints.append(y)
    upoints.append(u)
    exactpoints.append(exact(x))

    m1 = h*u
    k1 = h*F(y, u, x) 
    

    m2 = h*(u + 0.5*k1)
    k2 = h*F(y+0.5*m1, u+0.5*k1, x+0.5*h)

    m3 = h*(u + 0.5*k2)
    k3 = h*F(y+0.5*m2, u+0.5*k2, x+0.5*h)

    m4 = h*(u + k3)
    k4 = h*F(y+m3, u+k3, x+h)

    y += (m1 + 2*m2 + 2*m3 + m4)/6
    u += (k1 + 2*k2 + 2*k3 + k4)/6




plt.plot(xpoints, ypoints, 'bo--',label='Approximate (RK4)')
plt.plot(xpoints, exactpoints, 'g', label='Exact')

plt.xlabel('x')
plt.ylabel('f(x)')
plt.grid()
plt.legend(loc='lower right')
plt.show()

for xx, yy in zip(xpoints, ypoints):
    print("x =", xx, " y =", yy)
# Out:
# x = 0.0  y = 0
# x = 0.1  y = 0.3909368924370615
# x = 0.2  y = 0.6178308309844314
# x = 0.30000000000000004  y = 0.742293078297358
# x = 0.4  y = 0.8063473210409928
# x = 0.5  y = 0.8380866412609683
# x = 0.6000000000000001  y = 0.8557615077527113
# x = 0.7000000000000001  y = 0.8707247937189059
# x = 0.8  y = 0.8895458775120972
# x = 0.9  y = 0.9155221007173486
# x = 1.0  y = 0.9497543092748661
# x = 1.1  y = 0.9919080326174029
# x = 1.2000000000000002  y = 1.0407487415315135
# x = 1.3  y = 1.0945153801993677
# x = 1.4000000000000001  y = 1.1511786417056524
# x = 1.5  y = 1.2086175176488048
# x = 1.6  y = 1.2647382262389668
# x = 1.7000000000000002  y = 1.3175527709917456
# x = 1.8  y = 1.3652294137540277
# x = 1.9000000000000001  y = 1.4061237542727876
# x = 2.0  y = 1.4387965216160552
# x = 2.1  y = 1.4620223275117332
# x = 2.2  y = 1.4747923081401348
# x = 2.3000000000000003  y = 1.4763126428310804
# x = 2.4000000000000004  y = 1.4660002786279507
# x = 2.5  y = 1.4434767308637237
# x = 2.6  y = 1.4085605150188685
# x = 2.7  y = 1.3612585529842454
# x = 2.8000000000000003  y = 1.3017567575606013
# x = 2.9000000000000004  y = 1.2304099109926658
# x = 3.0  y = 1.1477309009923553

# %%
import numpy as np
import matplotlib.pyplot as plt

def F(y, u, x):
    return np.cos(x) - 4 * y

import numpy as np

def runge_kutta_2nd_order(h, x_range, initial_y, initial_u):
    xpoints = np.arange(x_range[0], x_range[1] + h, h)
    ypoints = []
    upoints = []

    y = initial_y
    u = initial_u

    for x in xpoints:
        ypoints.append(y)
        upoints.append(u)

        m1 = h * u
        k1 = h * F(y, u, x)

        m2 = h * (u + 0.5 * k1)
        k2 = h * F(y + 0.5 * m1, u + 0.5 * k1, x + 0.5 * h)

        y += 0.5 * (m1 + m2)
        u += 0.5 * (k1 + k2)

    return xpoints, ypoints


def plot_runge_kutta(xpoints, ypoints, label):
    plt.plot(xpoints, ypoints, label=label)
    plt.xlabel('x')
    plt.ylabel('f(x)')
    plt.grid()
    plt.legend()
    plt.show()

def print_results(xpoints, ypoints):
    for xx, yy in zip(xpoints, ypoints):
        print("x =", xx, " y =", yy)

# Example usage:
h_value = 0.1
x_range_values = (0, np.pi / 4)

initial_value1 = 0
initial_guess1 = 24
initial_value2 = 0
initial_guess2 = 76

xpoints1, ypoints1 = runge_kutta_2nd_order(h_value, x_range_values, initial_value1, initial_guess1)
plot_runge_kutta(xpoints1, ypoints1, label='Approximate (RK2) - Initial Guess 1')

xpoints2, ypoints2 = runge_kutta_2nd_order(h_value, x_range_values, initial_value2, initial_guess2)
plot_runge_kutta(xpoints2, ypoints2, label='Approximate (RK2) - Initial Guess 2')

dydx=(initial_guess2-initial_guess1)*(0-ypoints1[-1])/(ypoints2[-1]-ypoints1[-1])+initial_guess1
xpoints, ypoints = runge_kutta_2nd_order(h_value, x_range_values, 0, dydx)
plot_runge_kutta(xpoints, ypoints,'best')

# %%
# upwind central 

import numpy as np
import matplotlib.pyplot as plt

# Parameters
v = 1.0
L = 1.0  # Length of the spatial domain
T = 1.0  # Total simulation time
dx = 0.01  # Spatial step size
dt = dx / 2.0  # Temporal step size
Nx = int(L / dx) + 1  # Number of spatial grid points
Nt = int(T / dt) + 1  # Number of temporal grid points

# Initial condition
u0 = np.ones(Nx)

# Initialize solution arrays
u_central = np.zeros((Nt, Nx))
u_upwind = np.zeros((Nt, Nx))

# Set initial condition
u_central[0, :] = u0
u_upwind[0, :] = u0

# Central Difference Scheme
for n in range(0, Nt - 1):
    for i in range(1, Nx - 1):
        u_central[n + 1, i] = u_central[n, i] - v * dt / (2 * dx) * (u_central[n, i + 1] - u_central[n, i - 1])

# Upwind Scheme
for n in range(0, Nt - 1):
    for i in range(1, Nx):
        u_upwind[n + 1, i] = u_upwind[n, i] - v * dt / dx * (u_upwind[n, i] - u_upwind[n, i - 1])

# Plotting
x_values = np.linspace(0, L, Nx)

# Plot central difference scheme
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.title('Central Difference Scheme')
plt.xlabel('x')
plt.ylabel('u(x, t)')
for n in range(0, Nt, int(Nt / 10)):
    plt.plot(x_values, u_central[n, :], label=f't = {n * dt:.2f}')
plt.legend()

# Plot upwind scheme
plt.subplot(1, 2, 2)
plt.title('Upwind Scheme')
plt.xlabel('x')
plt.ylabel('u(x, t)')
for n in range(0, Nt, int(Nt / 10)):
    plt.plot(x_values, u_upwind[n, :], label=f't = {n * dt:.2f}')
plt.legend()

plt.tight_layout()
plt.show()

# %%
from math import e
def base_desnity(x):
    return e** (-(x**2))
def g(x):
    return (x**2)*(e**(x-1))
def trapezoidal(start,end,n,f):
    h=(end-start)/n
    result=f(start)+f(end)
    for i in range(1,n):
        result += 2*f(start+i*h)
    result*=h/2
    return result  
trapezoidal(0,1,100,g)
def simpsons(start,end,n,f):
    h=(end-start)/n
    x=list()
    fx=list()
    i=0
    while i<=n:
        x.append(start+i*h)
        fx.append(f(x[i]))
        i+=1
    res=0
    i=0
    while i<=n:
        if i==0 or i==n:
            res+=fx[i]
        elif i%2==1:
            res+=4*fx[i]
        else:
            res+=2*fx[i]
        i+=1
    res=res*(h/3)
    return res
simpsons(0,1,100,g)
A=1/simpsons(-10,10,1000,base_desnity)
A
# Out:
# 0.5641895835477554

# %%
import numpy as np

def f(x, y):
    return (y ** 2) - x

xs = np.linspace(0, 1, 100)
hx = (1 - 0) / len(xs)

result = 0


for x in xs:
    start=(x-2)**2
    end=6
    n=100
    ys=np.linspace(start,end,n)
    hy=(end-start)/n
    result_y=0
    for y in ys:
        result_y+=f(x,y)
    result+=result_y*hy

print( result*hx)
# Out:
# 63.91334271928978

# %%
import numpy as np
import matplotlib.pyplot as plt


def heat_conduction_solver(L, T, Nx, Nt, alpha):
    dx = L / Nx
    dt = T / Nt
    r = alpha * dt / dx**2

    # Initialize grid
    x = np.linspace(0, L, Nx + 1)
    t = np.linspace(0, T, Nt + 1)
    u = np.zeros((Nt + 1, Nx + 1))

    
    u[0, :]=np.sin(np.pi * x*3*0.5)
    u[:,0]=0

    
    for n in range(0, Nt):
        for i in range(1, Nx):
            u[n + 1, i] = u[n, i] + r * (u[n, i + 1] - 2 * u[n, i] + u[n, i - 1])

    return x, t, u

# Parameters
L = 1.0 
T = 0.1 
Nx = 50 
Nt = 500 
alpha = 1


x, t, u = heat_conduction_solver(L, T, Nx, Nt, alpha)
X, T = np.meshgrid(x, t)


fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, T, u, cmap='viridis', rstride=5, cstride=5, alpha=0.7)

ax.set_xlabel('Position (x)')
ax.set_ylabel('Time (t)')
ax.set_zlabel('u(x, t)')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Constants
L = 100 # Plate side length
segments = 20 # Number of segments
dx = dy = L / (segments - 1) # Grid increment
dt = 0.01 # Time step (adjust as needed)

# Create grid
x = np.linspace(0, L, segments)
y = np.linspace(0, L, segments)
X, Y = np.meshgrid(x, y)

# Initial conditions
T = np.zeros_like(X)
T[:, 0] = 0 # T(x=0) = 0
T[:, -1] = 0 # T(x=L) = 0
T[0, :] = -100 # T(y=0) = -100
T[-1, :] = 100 # T(y=L) = 100
T[0, 0] = T[0, -1] = T[-1, 0] = T[-1, -1] = (T[0, 1] + T[1, 0]) / 2 # Corner points

# Crank-Nicolson method
alpha = 0.5 * dt / dx**2
beta = 0.5 * dt / dy**2

for _ in range(1000): 
    Tn = T.copy()
    for i in range(1, segments - 1):
        for j in range(1, segments - 1):
            T[i, j] = alpha * (Tn[i + 1, j] - 2 * Tn[i, j] + Tn[i - 1, j]) + beta * (Tn[i, j + 1] - 2 * Tn[i, j] + Tn[i, j - 1])
            T[i, j] /= 1 + 2 * (alpha + beta)

# Surface plot
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, T)

ax.set_xlabel('Position(X)')
ax.set_ylabel('Position(Y)')
ax.set_zlabel('Temp')


# Show plot
plt.show()
